# %%
import json

path = r"C:\Users\Soret\credit-risk-model\notebooks\eda.ipynb"

with open(path, "r", encoding="utf-8") as f:
    json.load(f)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[1], line 6
#       2
#       3 path = r"C:\Users\Soret\credit-risk-model\notebooks\eda.ipynb"
#       4
#       5 with open(path, "r", encoding="utf-8") as f:
# ----> 6     json.load(f)
#
# File C:\Program Files\Python314\Lib\json\__init__.py:298, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     278 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     279         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     280     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     281     a JSON document) to a Python object.
#     282
#    (...)    296     kwarg; otherwise ``JSONDecoder`` is used.
#     297     """
# --> 298     return loads(fp.read(),
#     299         cls=cls, object_hook=object_hook,
# ...
